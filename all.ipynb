# %%
import pandas as pd
import numpy as npx
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error
data = pd.read_csv('winequality-white.csv', sep=';', encoding='utf-8')
display(data, data.describe(), data.info(), data.dtypes)
data.value_counts()
sns.pairplot(data)
for i in data.columns:
    sns.kdeplot(data[i], shade=True, color='r')
    plt.show()
sns.kdeplot(data['fixed acidity'], shade=True, color='r')
data['alcohol'].round(decimals=1)
ny_data =data.corr()
sns.set(rc={"figure.figsize":(10, 5)})
sns.heatmap(ny_data, annot=True, cmap='Reds', linewidths=0.2)
X = data.drop(['alcohol', 'quality'], axis=1)
y = data['alcohol']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Créer le modèle de régression linéaire multiple
model = LinearRegression().fit(X_train, y_train)

# Faire des prédictions sur l'ensemble de test
y_pred = model.predict(y_test)
x_pred = model.predict(X_test)

# Évaluer la performance du modèle
score = model.score(X_test, y_test)
accuracy = r2_score(y_test, y_pred)
print(f"Le coefficient de détermination R² du modèle est : {score:.2f}")
print(f"L'accuracy  du modèle est : {accuracy:.2f}")
print (f" accuracy : {accuracy:.2f}")
mean_squared_error(y_test, y_pred)
print(f"La racine carrée de l'erreur quadratique moyenne est : {mean_squared_error(y_test, y_pred):.2f}")
print (f" accuracy : {accuracy:.2f}")
mean_squared_error(y_test, y_pred)
print(f"La racine carrée de l'erreur quadratique moyenne est : {mean_squared_error(y_test, y_pred):.2f}")
mean_squared_error(y_test, y_pred)
scaler = StandardScaler()

# Adapter les données
scaler.fit(X)

# Transformer les données
X_scaled = scaler.transform(X)

fig = plt.figure(figsize=(10, 6))
plt.scatter(y_pred, y_test, color='red')

plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# ...
